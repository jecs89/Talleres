# %% [markdown]
# <center>
# <img src="https://www.techrepublic.com/a/hub/i/r/2021/06/03/1130ef3e-48cf-4d60-8b86-ca6a6d9bf51f/resize/1200x/526f97f4e170b0a301a7e2a494c727b0/python-code-developer-programming.jpg" width="700" height="200" />>
#
# ##  Workshop Python 2021-I ( 16 Agosto )
#
# Autor: [Josimar Chire](https://github.com/jecs89).\
# Institución: Research4Tech\
# Correo: jecs89@gmail.com
#
# Este material está sujeto a los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Se permite el uso gratuito para cualquier propósito no comercial.

# %% [markdown]
# # <center> Variáveis

# %% [markdown]
# <center>
# <img src="https://api.time.com/wp-content/uploads/2014/09/macaca_nigra_self-portrait_rotated_and_cropped.jpg" width="250" height="300" />>

# %% [markdown]
# <center>
# <img src="https://yt3.ggpht.com/ytc/AKedOLSKZ-NJuFhTMoRljXZQ9vqGyH8geBFPw5sX7jQl=s900-c-k-c0x00ffffff-no-rj" width="250" height="300" />>

# %% [markdown]
# <center>
# <img src="
# https://www.teclasap.com.br/wp-content/uploads/2014/05/monkey-1.jpg" width="500" height="300" />>

# %%
#Kong
nome = 'Kong'
bananas = 27
emultiplode5 = False

# %%
type(emultiplode5), type(nome), type(bananas)
# Out:
# (bool, str, int)

# %%
if bananas % 5 == 0                  :
  print('Sou multiplo de 5')
elif bananas % 3 == 0:
  print('Sou 3')
elif bananas % 7 == 0:
  print('Sou 7')
# Out:
# Sou 3

# %%
bananas % 5 == 0 or bananas % 7 == 0 and bananas % 10 == 0
# Out:
# False

# %%
i = 1
bananascomidas = 0
while i <= bananas:
  if i % 5 == 0:
    print('Come macaco', i)
    bananascomidas = bananascomidas + 1
  i = i + 1

print(bananascomidas)
# Out:
# Come macaco 5
# Come macaco 10
# Come macaco 15
# Come macaco 20
# Come macaco 25
# 5

# %%
lista = [ 37, 30, 42, 94, 88, 64, 20, 66, 77, 15 ]
print(type(lista))
# Out:
# <class 'list'>

# %%
i = 0
bananascomidas = 0

while i < len(lista):
  # print(lista[i])
  j = 1
  
  while j <= bananas:
    if j % 5 == 0:
      # print('Come macaco', i)
      bananascomidas = bananascomidas + 1
    j = j + 1
  i += 1
  
print(bananascomidas)
# Out:
# 50

# %%
####
minimo = 1000
i = 0
while i <= len(lista):
# Out:
# 10

# %%
# !wget https://thumbs.dreamstime.com/b/angry-looking-rhesus-macaque-monkey-maharashtra-india-140770431.jpg
# !mv angry-looking-rhesus-macaque-monkey-maharashtra-india-140770431.jpg angry.jpg
# !wget https://images-cdn.9gag.com/photo/ad6XVOD_700b.jpg
# !mv ad6XVOD_700b.jpg happy.jpg
# Out:
# --2021-08-16 16:55:50--  https://thumbs.dreamstime.com/b/angry-looking-rhesus-macaque-monkey-maharashtra-india-140770431.jpg
# Resolving thumbs.dreamstime.com (thumbs.dreamstime.com)... 192.229.163.122
# Connecting to thumbs.dreamstime.com (thumbs.dreamstime.com)|192.229.163.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51746 (51K) [image/jpeg]
# Saving to: ‘angry-looking-rhesus-macaque-monkey-maharashtra-india-140770431.jpg’
#
# angry-looking-rhesu 100%[===================>]  50.53K  --.-KB/s    in 0.006s
#
# 2021-08-16 16:55:50 (8.70 MB/s) - ‘angry-looking-rhesus-macaque-monkey-maharashtra-india-140770431.jpg’ saved [51746/51746]
#
# --2021-08-16 16:55:51--  https://images-cdn.9gag.com/photo/ad6XVOD_700b.jpg
# Resolving images-cdn.9gag.com (images-cdn.9gag.com)... 104.16.106.144, 104.16.103.144, 104.16.104.144, ...
# Connecting to images-cdn.9gag.com (images-cdn.9gag.com)|104.16.106.144|:443... connected.
# ...

# %%
import matplotlib.pyplot as plt
import cv2 as cv
angry = cv.imread('angry.jpg')
happy = cv.imread('happy.jpg')
fig = plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(angry[:,:,::-1])
plt.subplot(1,2,2)
plt.imshow(happy[:,:,::-1])
plt.show()

# %% [markdown]
# ## Donaciones/Donations
# <br>
# <center>
# Si la información de esta notebook te ayudó. <br>
# Puedes donar una vez en el siguiente enlace (Ko-Fi):
#
# <br>
#
# *Click en la imagen.*
#
# <a href="https://ko-fi.com/research4tech">
# <img src="https://habrastorage.org/webt/8r/ml/xf/8rmlxfpdzukegpxa62cxlfvgkqe.png" width=20% />
#
# </center>
