# %% [markdown]
# <center>
# <img src="https://www.techrepublic.com/a/hub/i/r/2021/06/03/1130ef3e-48cf-4d60-8b86-ca6a6d9bf51f/resize/1200x/526f97f4e170b0a301a7e2a494c727b0/python-code-developer-programming.jpg" width="700" height="200" />>
#
# ##  Workshop Python 2021-I ( 17 Agosto )
#
# Autor: [Josimar Chire](https://github.com/jecs89).\
# Institución: Research4Tech\
# Correo: jecs89@gmail.com
#
# Este material está sujeto a los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Se permite el uso gratuito para cualquier propósito no comercial.

# %% [markdown]
# # <center> Funcoes e Strings

# %%
lista = [ 37, 30, 42, 94, 88, 64, 20, 66, 77, 15 ]
# bananas = 27
i = 0
bananascomidas = 0

while i < len(lista):
  # print(lista[i])
  j = 1
  
  while j <= lista[i]:
    if j % 5 == 0:
      # print('Come macaco', i)
      bananascomidas = bananascomidas + 1
    j = j + 1
  i += 1
porc = 0.10  
print(bananascomidas)
print(bananascomidas*0.1)
# Out:
# 103
# 10.3

# %%
def calculo(lista, porc):
  i = 0
  bananascomidas = 0
  while i < len(lista):
    j = 1
    
    while j <= lista[i]:
      if j % 5 == 0:
        bananascomidas = bananascomidas + 1
      j = j + 1
    i += 1
  return bananascomidas*porc

# %%
import random
ano = []
i = 0
while i < 365:
  # print(random.random()*100)
  ano.append(int(random.random()*100))
  i += 1
print(ano)
# Out:
# [63, 24, 19, 19, 19, 5, 39, 53, 71, 28, 83, 89, 96, 76, 70, 2, 88, 63, 27, 79, 73, 89, 78, 15, 50, 99, 31, 51, 56, 82, 90, 28, 50, 50, 47, 55, 23, 24, 99, 94, 6, 84, 33, 87, 27, 3, 11, 54, 35, 71, 89, 54, 68, 96, 91, 88, 24, 74, 60, 15, 36, 47, 48, 12, 98, 74, 61, 56, 5, 45, 74, 39, 78, 1, 68, 33, 96, 15, 19, 11, 81, 50, 30, 99, 8, 24, 98, 7, 95, 94, 33, 3, 15, 70, 59, 66, 60, 62, 14, 38, 68, 95, 66, 20, 87, 54, 41, 95, 69, 51, 1, 78, 68, 28, 93, 68, 89, 0, 98, 45, 25, 65, 61, 62, 39, 13, 42, 28, 53, 1, 52, 86, 35, 64, 22, 88, 79, 77, 43, 36, 24, 83, 58, 46, 51, 92, 48, 30, 14, 88, 29, 82, 67, 11, 77, 76, 16, 2, 81, 58, 74, 34, 75, 85, 24, 23, 73, 41, 32, 82, 89, 95, 48, 72, 76, 46, 99, 78, 8, 32, 71, 14, 32, 19, 62, 14, 58, 49, 47, 41, 19, 90, 75, 40, 26, 87, 42, 63, 23, 78, 86, 81, 87, 21, 56, 83, 69, 31, 12, 98, 55, 97, 23, 66, 57, 75, 41, 99, 50, 88, 13, 3, 95, 7, 87, 61, 14, 58, 18, 28, 11, 77, 99, 56, 69, 27, 58, 6, 68, 55, 18, 48, 7, 65, 28, 56, 84, 17, 73, 59, 18, 58, 15, 92,
# ...

# %%
porc = 0.13
valorbanana = 3 #reais
print( calculo(ano, porc) * valorbanana )
# Out:
# 1419.9900000000002

# %%
texto = 'ola 12312 ~^123123¬|@~~½¬¬{·½·½~'
# texto[0:3]
texto[texto.find("@"):]
# Out:
# '@~~½¬¬{·½·½~'

# %%
fuente = """Sold 34.06 BANANA (119.6212 $) for 0.285 WBNB on Unknown Swap

💔

1 WBNB = 419.7237 $
1 BANANA = 3.512 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools6
12:53

👹 Sold 3.2098 BANANA (11.2732 $) for 0.0268 WBNB on Unknown Swap

💔

1 WBNB = 420.6445 $
1 BANANA = 3.5121 $

Pool: 6,472,893.9077 BANANA + 54,272.0851 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter8
12:53

👹 Sold 34.06 BANANA (119.62 $) for 0.285 WBNB on Unknown Swap

💔

1 WBNB = 419.7193 $
1 BANANA = 3.512 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools8
12:53

🚀 Bought 1,509.4277 BANANA (5,330 $) for 5,330 BUSD on ApeSwapV2

💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚

1 BANANA = 3.5311 $
1 BUSD = 1 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools9
12:54

🚀 Bought 1.0646 BANANA (3.7549 $) for 0.0089 WBNB on ApeSwapV2

💚

1 BANANA = 3.527 $
1 WBNB = 421.9044 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter8
12:55

🚀 Bought 0.6384 BANANA (2.2516 $) for 0.0053 WBNB on ApeSwapV2

💚

1 BANANA = 3.527 $
1 WBNB = 424.8452 $

Pool: 6,472,892.2045 BANANA + 54,272.0994 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter12
12:55

👹 Sold 115.3322 BANANA (405.8686 $) for 405.8686 BUSD on ApeSwapV2

💔💔💔💔

1 BUSD = 1 $
1 BANANA = 3.5191 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter11
12:55

👹 Sold 8.3924 BANANA (29.4805 $) for 0.0702 WBNB on ApeSwapV2

💔

1 WBNB = 419.9511 $
1 BANANA = 3.5127 $

Pool: 6,472,864.955 BANANA + 54,271.7303 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter10
12:56

🚀 Bought 153 BANANA (539.6115 $) for 1.2854 WBNB on ApeSwapV2

💚💚💚💚💚

1 BANANA = 3.5268 $
1 WBNB = 419.8004 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter7
12:56

👹 Sold 26.9032 BANANA (94.6701 $) for 94.6701 BUSD on ApeSwapV2

💔

1 BUSD = 1 $
1 BANANA = 3.5189 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools6
12:56

🚀 Bought 103.8378 BANANA (366.2279 $) for 0.8724 WBNB on ApeSwapV2

💚💚💚

1 BANANA = 3.5269 $
1 WBNB = 419.7936 $

Pool: 6,472,608.1172 BANANA + 54,273.8882 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools6
12:56

🚀 Bought 8.0207 BANANA (28.2877 $) for 0.0673 WBNB on ApeSwapV2

💚

1 BANANA = 3.5268 $
1 WBNB = 420.3224 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools4
12:56

👹 Sold 13.9064 BANANA (48.9346 $) for 48.9346 BUSD on ApeSwapV2

💔

1 BUSD = 1 $
1 BANANA = 3.5188 $

Pool: 6,472,600.0964 BANANA + 54,273.9555 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter4
12:56

👹 Sold 3.3217 BANANA (11.6685 $) for 0.0277 WBNB on Unknown Swap

💔

1 WBNB = 421.2472 $
1 BANANA = 3.5128 $

Pool: 6,472,673.9135 BANANA + 54,273.3378 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools4
12:56

👹 Sold 35.2476 BANANA (123.8141 $) for 0.2949 WBNB on Unknown Swap

💔

1 WBNB = 419.8514 $
1 BANANA = 3.5126 $

Pool: 6,472,673.9135 BANANA + 54,273.3378 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
12:56

👹 Sold 35.2476 BANANA (123.8148 $) for 0.2949 WBNB on Unknown Swap

💔

1 WBNB = 419.8538 $
1 BANANA = 3.5127 $

Pool: 6,472,600.0964 BANANA + 54,273.3378 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools6
12:56

🚀 Bought 10 BANANA (35.2682 $) for 0.084 WBNB on ApeSwapV2

💚

1 BANANA = 3.5268 $
1 WBNB = 419.8596 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
12:57

🚀 Bought 70.1625 BANANA (247.4416 $) for 0.5895 WBNB on ApeSwapV2

💚💚

1 BANANA = 3.5266 $
1 WBNB = 419.7482 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter7
12:57

👹 Sold 141.5163 BANANA (497.0528 $) for 1.1842 WBNB on ApeSwapV2

💔💔💔💔

1 WBNB = 419.7372 $
1 BANANA = 3.5123 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter7
12:57

🚀 Bought 141.5163 BANANA (500 $) for 500 BUSD on ApeSwapV2

💚💚💚💚💚

1 BANANA = 3.5331 $
1 BUSD = 1 $

Pool: 6,472,746.751 BANANA + 54,275.2942 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools9
12:57

👹 Sold 17.4598 BANANA (61.445 $) for 61.445 BUSD on ApeSwapV2

💔

1 BUSD = 1 $
1 BANANA = 3.5192 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter8
12:57

👹 Sold 2.3502 BANANA (8.2709 $) for 8.2709 BUSD on ApeSwapV2

💔

1 BUSD = 1 $
1 BANANA = 3.5192 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter8
12:58

🚀 Bought 12.9269 BANANA (45.5826 $) for 0.1086 WBNB on ApeSwapV2

💚

1 BANANA = 3.5261 $
1 WBNB = 419.7299 $

Pool: 6,472,875.3404 BANANA + 54,274.2186 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools8
12:58

🚀 Bought 1.333 BANANA (4.7101 $) for 4.7101 BUSD on ApeSwapV2

💚

1 BANANA = 3.5335 $
1 BUSD = 1 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter4
12:58

👹 Sold 34.0243 BANANA (119.5018 $) for 0.2847 WBNB on ApeSwapV2

💔

1 WBNB = 419.7465 $
1 BANANA = 3.5122 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools4
12:58

🚀 Bought 6.078 BANANA (21.4332 $) for 0.051 WBNB on ApeSwapV2

💚

1 BANANA = 3.5263 $
1 WBNB = 420.259 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter4
12:58

👹 Sold 501.5787 BANANA (1,761.539 $) for 4.1969 WBNB on ApeSwapV2

💔💔💔💔💔💔💔💔💔💔💔💔💔💔💔💔💔

1 WBNB = 419.7238 $
1 BANANA = 3.5119 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools5
12:58

🚀 Bought 2.2636 BANANA (7.9981 $) for 7.9981 BUSD on ApeSwapV2

💚

1 BANANA = 3.5333 $
1 BUSD = 1 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter5
12:58

👹 Sold 62.3752 BANANA (219.0393 $) for 0.5218 WBNB on ApeSwapV2

💔💔

1 WBNB = 419.7764 $
1 BANANA = 3.5116 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools4
12:59

🚀 Bought 36.0851 BANANA (127.2218 $) for 0.3031 WBNB on ApeSwapV2

💚

1 BANANA = 3.5256 $
1 WBNB = 419.7357 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools4
12:59

🚀 Bought 10.1188 BANANA (35.6748 $) for 0.085 WBNB on ApeSwapV2

💚

1 BANANA = 3.5256 $
1 WBNB = 419.7041 $

Pool: 6,473,467.2408 BANANA + 54,269.6543 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools7
12:59

🚀 Bought 282.9053 BANANA (999.7173 $) for 999.7173 BUSD on ApeSwapV2

💚💚💚💚💚💚💚💚💚

1 BANANA = 3.5337 $
1 BUSD = 1 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
12:59

🚀 Bought 20.9658 BANANA (73.9155 $) for 0.1761 WBNB on ApeSwapV2

💚

1 BANANA = 3.5255 $
1 WBNB = 419.7361 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools6
12:59

🚀 Bought 3.5496 BANANA (12.5649 $) for 0.0299 WBNB on PancakeSwapV2

💚

1 BANANA = 3.5398 $
1 WBNB = 420.2309 $

Pool: 6,473,400.0709 BANANA + 54,269.8304 WBNB and 12 other pools
Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
12:59

🚀 Bought 41.593 BANANA (147 $) for 147 BUSD on ApeSwapV2

💚

1 BANANA = 3.5342 $
1 BUSD = 1 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
12:59

🚀 Bought 12.5672 BANANA (44.3063 $) for 0.1055 WBNB on ApeSwapV2

💚

1 BANANA = 3.5255 $
1 WBNB = 419.9655 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools7
12:59

👹 Sold 0.0277 BANANA (0.0973 $) for 0.0002 WBNB on Unknown Swap

💔

1 WBNB = 486.5182 $
1 BANANA = 3.5127 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
13:00

👹 Sold 8.764 BANANA (30.7746 $) for 0.0733 WBNB on Unknown Swap

💔

1 WBNB = 419.8454 $
1 BANANA = 3.5114 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
13:00

👹 Sold 83.2586 BANANA (292.3552 $) for 0.6965 WBNB on Unknown Swap

💔💔

1 WBNB = 419.749 $
1 BANANA = 3.5114 $

Buy BANANA | 📶 Tx Hash | 💹 Charts: Bogged | Poocoin | Dextools

Be aware of new BinanceRocket Channels 👉 @BinanceRocketChannel or Twitter6
13:00
"""

# %%
query = '1 BANANA ='
prices = []
while fuente.find(query) != -1:
  idx = fuente.find(query)
  # print( fuente[idx+11:idx+17] )
  prices.append( float( fuente[idx+11:idx+17] ) )
  fuente = fuente[idx+17:]
# Out:
# 3.512
# 3.5121
# 3.512
# 3.5311
# 3.527
# 3.527
# 3.5191
# 3.5127
# 3.5268
# 3.5189
# 3.5269
# 3.5268
# 3.5188
# 3.5128
# 3.5126
# 3.5127
# 3.5268
# 3.5266
# 3.5123
# 3.5331
# 3.5192
# 3.5192
# 3.5261
# 3.5335
# 3.5122
# 3.5263
# 3.5119
# 3.5333
# 3.5116
# 3.5256
# 3.5256
# 3.5337
# 3.5255
# 3.5398
# 3.5342
# 3.5255
# 3.5127
# 3.5114
# 3.5114

# %%
import numpy as np

troco = 5.27
avg_price = np.array( prices ).mean() * troco
print('Avg Cost: ', avg_price )

poupanca = calculo(ano, porc) * valorbanana

print('Bananas digitais compradas:', poupanca/avg_price)
# Out:
# Avg Cost:  18.559426564102562
# Bananas digitais compradas: 76.51044578858537
